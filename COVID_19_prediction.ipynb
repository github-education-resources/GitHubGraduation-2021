# %% [markdown]
# <a href="https://colab.research.google.com/github/arnab8335/GitHubGraduation-2021/blob/arnab8335-patch-1/COVID_19_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
covid = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')

# %%
covid.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.511
# 1      AFG      Asia  ...           64.83                   0.511
# 2      AFG      Asia  ...           64.83                   0.511
# 3      AFG      Asia  ...           64.83                   0.511
# 4      AFG      Asia  ...           64.83                   0.511
#
# [5 rows x 59 columns]

# %%
covid.head
# Out:
# <bound method NDFrame.head of       iso_code continent  ... life_expectancy human_development_index
# 0          AFG      Asia  ...           64.83                   0.511
# 1          AFG      Asia  ...           64.83                   0.511
# 2          AFG      Asia  ...           64.83                   0.511
# 3          AFG      Asia  ...           64.83                   0.511
# 4          AFG      Asia  ...           64.83                   0.511
# ...        ...       ...  ...             ...                     ...
# 91904      ZWE    Africa  ...           61.49                   0.571
# 91905      ZWE    Africa  ...           61.49                   0.571
# 91906      ZWE    Africa  ...           61.49                   0.571
# 91907      ZWE    Africa  ...           61.49                   0.571
# 91908      ZWE    Africa  ...           61.49                   0.571
#
# [91909 rows x 59 columns]>

# %%
covid.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
covid["location"].value_counts()
# Out:
# Argentina                          514
# Mexico                             514
# Thailand                           511
# Peru                               509
# Taiwan                             499
#                                   ...
# Pitcairn                             2
# Bonaire Sint Eustatius and Saba      1
# Tuvalu                               1
# Turkmenistan                         1
# British Virgin Islands               1
# Name: location, Length: 229, dtype: int64

# %%
covid.describe(include='O')
# Out:
#        iso_code continent   location        date      tests_units
# count     91909     87546      91909       91909            49741
# unique      229         6        229         514                4
# top         ARG    Africa  Argentina  2021-04-27  tests performed
# freq        514     23793        514         222            30971

# %%
covid.isna().any()
# Out:
# iso_code                                 False
# continent                                 True
# location                                 False
# date                                     False
# total_cases                               True
# new_cases                                 True
# new_cases_smoothed                        True
# total_deaths                              True
# new_deaths                                True
# new_deaths_smoothed                       True
# total_cases_per_million                   True
# new_cases_per_million                     True
# new_cases_smoothed_per_million            True
# total_deaths_per_million                  True
# new_deaths_per_million                    True
# new_deaths_smoothed_per_million           True
# reproduction_rate                         True
# icu_patients                              True
# icu_patients_per_million                  True
# hosp_patients                             True
# ...

# %%
covid.isna().sum()
# Out:
# iso_code                                     0
# continent                                 4363
# location                                     0
# date                                         0
# total_cases                               2762
# new_cases                                 2763
# new_cases_smoothed                        3775
# total_deaths                             12653
# new_deaths                               12495
# new_deaths_smoothed                       3775
# total_cases_per_million                   3239
# new_cases_per_million                     3240
# new_cases_smoothed_per_million            4247
# total_deaths_per_million                 13117
# new_deaths_per_million                   12959
# new_deaths_smoothed_per_million           4247
# reproduction_rate                        17990
# icu_patients                             82594
# icu_patients_per_million                 82594
# hosp_patients                            80328
# ...

# %%
india_case = covid[covid["location"]=="India"]

# %%
india_case.head()
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 37996      IND      Asia  ...           69.66                   0.645
# 37997      IND      Asia  ...           69.66                   0.645
# 37998      IND      Asia  ...           69.66                   0.645
# 37999      IND      Asia  ...           69.66                   0.645
# 38000      IND      Asia  ...           69.66                   0.645
#
# [5 rows x 59 columns]

# %%
india_case.tail()
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 38476      IND      Asia  ...           69.66                   0.645
# 38477      IND      Asia  ...           69.66                   0.645
# 38478      IND      Asia  ...           69.66                   0.645
# 38479      IND      Asia  ...           69.66                   0.645
# 38480      IND      Asia  ...           69.66                   0.645
#
# [5 rows x 59 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.set(rc={'figure.figsize' :(15,10)})
sns.lineplot(x="date",y="total_cases",data=india_case)
plt.show()

# %%
india_last_5_days = india_case.tail();

# %%
sns.set(rc={'figure.figsize' :(15,10)})
sns.lineplot(x="date",y="total_cases",data=india_last_5_days)
plt.show()

# %%
sns.set(rc={'figure.figsize' :(15,10)})
sns.lineplot(x="date",y="total_tests",data=india_case)
plt.show()

# %%
sns.set(rc={'figure.figsize' :(15,10)})
sns.lineplot(x="date",y="total_tests",data=india_last_5_days)
plt.show()

# %%
pakistan_case = covid[covid["location"]=="Pakistan"]

# %%
pakistan_case.head()
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 63153      PAK      Asia  ...           67.27                   0.557
# 63154      PAK      Asia  ...           67.27                   0.557
# 63155      PAK      Asia  ...           67.27                   0.557
# 63156      PAK      Asia  ...           67.27                   0.557
# 63157      PAK      Asia  ...           67.27                   0.557
#
# [5 rows x 59 columns]

# %%
pakistan_case.tail()
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 63607      PAK      Asia  ...           67.27                   0.557
# 63608      PAK      Asia  ...           67.27                   0.557
# 63609      PAK      Asia  ...           67.27                   0.557
# 63610      PAK      Asia  ...           67.27                   0.557
# 63611      PAK      Asia  ...           67.27                   0.557
#
# [5 rows x 59 columns]

# %%
sns.set(rc={'figure.figsize' :(15,10)})
sns.lineplot(x="date",y="total_cases",data=pakistan_case)
plt.show()

# %%
india_china_japan_case = covid[(covid["location"]=="India") | (covid["location"]=="China") | (covid["location"]=="Japan")]

# %%
sns.set(rc={'figure.figsize' :(15,10)})
sns.lineplot(x="date",y="total_cases",data=india_china_japan_case, hue="date")
plt.show()

# %%
sns.set(rc={'figure.figsize' :(15,10)})
sns.lineplot(x="date",y="total_vaccinations",data=india_case)
plt.show()

# %%
germany_england_italy_case = covid[(covid["location"]=="Germany") | (covid["location"]=="England") | (covid["location"]=="Italy")]

# %%
sns.set(rc={'figure.figsize' :(15,10)})
sns.lineplot(x="date",y="total_cases",data=germany_england_italy_case)
plt.show()

# %%
last_day_cases=covid[covid["date"]=="2021-05-28"]
last_day_cases
# Out:
#        iso_code continent  ... life_expectancy human_development_index
# 459         AFG      Asia  ...           64.83                   0.511
# 930    OWID_AFR       NaN  ...             NaN                     NaN
# 1389        ALB    Europe  ...           78.57                   0.795
# 1848        DZA    Africa  ...           76.88                   0.748
# 2301        AND    Europe  ...           83.73                   0.868
# ...         ...       ...  ...             ...                     ...
# 90065       VNM      Asia  ...           75.40                   0.704
# 90622  OWID_WRL       NaN  ...           72.58                   0.737
# 91036       YEM      Asia  ...           66.12                   0.470
# 91473       ZMB    Africa  ...           63.89                   0.584
# 91908       ZWE    Africa  ...           61.49                   0.571
#
# [201 rows x 59 columns]

# %%
max_cases_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_cases_country
# Out:
#        iso_code      continent  ... life_expectancy human_development_index
# 90622  OWID_WRL            NaN  ...           72.58                   0.737
# 4802   OWID_ASI            NaN  ...             NaN                     NaN
# 28146  OWID_EUR            NaN  ...             NaN                     NaN
# 61151  OWID_NAM            NaN  ...             NaN                     NaN
# 87601       USA  North America  ...           78.86                   0.926
# ...         ...            ...  ...             ...                     ...
# 52587       MHL        Oceania  ...           73.70                   0.704
# 88683       VUT        Oceania  ...           70.47                   0.609
# 70729       WSM        Oceania  ...           73.32                   0.715
# 44231       KIR        Oceania  ...           68.37                   0.630
# 54107       FSM        Oceania  ...           67.88                   0.620
#
# [201 rows x 59 columns]

# %%
max_cases_country[1:6]
# Out:
#        iso_code      continent  ... life_expectancy human_development_index
# 4802   OWID_ASI            NaN  ...             NaN                     NaN
# 28146  OWID_EUR            NaN  ...             NaN                     NaN
# 61151  OWID_NAM            NaN  ...             NaN                     NaN
# 87601       USA  North America  ...           78.86                   0.926
# 28638  OWID_EUN            NaN  ...             NaN                     NaN
#
# [5 rows x 59 columns]

# %%
sns.barplot(x="date",y="total_tests",data=india_last_5_days)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
import datetime as dt
india_case['date'] = pd.to_datetime(india_case['date']) 
india_case.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       iso_code continent  ... life_expectancy human_development_index
# 37996      IND      Asia  ...           69.66                   0.645
# 37997      IND      Asia  ...           69.66                   0.645
# 37998      IND      Asia  ...           69.66                   0.645
# 37999      IND      Asia  ...           69.66                   0.645
# 38000      IND      Asia  ...           69.66                   0.645
#
# [5 rows x 59 columns]

# %%
india_case.head()
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 37996      IND      Asia  ...           69.66                   0.645
# 37997      IND      Asia  ...           69.66                   0.645
# 37998      IND      Asia  ...           69.66                   0.645
# 37999      IND      Asia  ...           69.66                   0.645
# 38000      IND      Asia  ...           69.66                   0.645
#
# [5 rows x 59 columns]

# %%
india_case['date']=india_case['date'].map(dt.datetime.toordinal)
india_case.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       iso_code continent  ... life_expectancy  human_development_index
# 37996      IND      Asia  ...           69.66                    0.645
# 37997      IND      Asia  ...           69.66                    0.645
# 37998      IND      Asia  ...           69.66                    0.645
# 37999      IND      Asia  ...           69.66                    0.645
# 38000      IND      Asia  ...           69.66                    0.645
#
# [5 rows x 59 columns]

# %%
x=india_case['date']
y=india_case['total_cases']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
import numpy as np
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
india_case.tail()
# Out:
#       iso_code continent  ... life_expectancy  human_development_index
# 38476      IND      Asia  ...           69.66                    0.645
# 38477      IND      Asia  ...           69.66                    0.645
# 38478      IND      Asia  ...           69.66                    0.645
# 38479      IND      Asia  ...           69.66                    0.645
# 38480      IND      Asia  ...           69.66                    0.645
#
# [5 rows x 59 columns]

# %%
india_case.tail()
# Out:
#       iso_code continent  ... life_expectancy  human_development_index
# 38476      IND      Asia  ...           69.66                    0.645
# 38477      IND      Asia  ...           69.66                    0.645
# 38478      IND      Asia  ...           69.66                    0.645
# 38479      IND      Asia  ...           69.66                    0.645
# 38480      IND      Asia  ...           69.66                    0.645
#
# [5 rows x 59 columns]

# %%
y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(x_test,y_pred)
# Out:
# 68821512573035.67

# %%
lr.predict(np.array([[737573]]))
# Out:
# array([[1121948.77526093]])
